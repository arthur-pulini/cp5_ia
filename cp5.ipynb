# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("wine_quality_general.csv", encoding="iso-8859-1", sep=';')
df.head()
# Out:
#   fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7              0.27         0.36            20.7      0.045
# 1           6.3              0.30         0.34             1.6      0.049
# 2           8.1              0.28         0.40             6.9      0.050
# 3           7.2              0.23         0.32             8.5      0.058
# 4           7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#   alcohol    tipo  quality  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# ...

# %% [markdown]
# ## Conhecendo o DataFame

# %%
df.shape
# Out:
# (6498, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6498 entries, 0 to 6497
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6498 non-null   object
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6468 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6467 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6457 non-null   object
#  11  tipo                  6460 non-null   object
#  12  quality               6497 non-null   float64
#  13  Unnamed: 13           0 non-null      float64
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity              0
# volatile acidity           1
# citric acid               30
# residual sugar             1
# chlorides                  1
# free sulfur dioxide       31
# total sulfur dioxide       1
# density                    1
# pH                         1
# sulphates                  1
# alcohol                   41
# tipo                      38
# quality                    1
# Unnamed: 13             6498
# Unnamed: 14             6498
# Unnamed: 15             6498
# Unnamed: 16             6498
# Unnamed: 17             6498
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 32638

# %%
df['fixed acidity'].value_counts()
# Out:
# fixed acidity
# 6.8                                354
# 6.6                                327
# 6.4                                305
# 7                                  282
# 6.9                                279
#                                   ...
# todos;os;dados;em;uma;só;célula      1
# 6.45                                 1
# 14                                   1
# 15.9                                 1
# 12.1                                 1
# Name: count, Length: 107, dtype: int64

# %%
df['alcohol'].value_counts()
# Out:
# alcohol
# 9.5                    365
# 9.4                    330
# 9.2                    270
# 10                     229
# 10.5                   227
#                       ...
# 10.65                    1
# 11.55                    1
# 963.333.333.333.333      1
# 12.05                    1
# 9.05                     1
# Name: count, Length: 113, dtype: int64

# %%
df['tipo'].value_counts()
# Out:
# tipo
# branco      4898
# vermelho    1562
# Name: count, dtype: int64

# %%
round(df.describe(), 2)
# Out:
#        volatile acidity  citric acid  residual sugar  chlorides  \
# count           6497.00      6468.00         6497.00    6497.00
# mean               1.16         0.32            5.44       0.06
# std               29.81         0.15            4.76       0.04
# min                0.08         0.00            0.60       0.01
# 25%                0.23         0.25            1.80       0.04
# 50%                0.29         0.31            3.00       0.05
# 75%                0.40         0.39            8.10       0.06
# max             1185.00         1.66           65.80       0.61
#
#        free sulfur dioxide  total sulfur dioxide    density       pH  \
# count              6467.00               6497.00    6497.00  6497.00
# mean                 30.50                115.74     310.62     3.22
# std                  17.76                 56.52    4883.18     0.16
# min                   1.00                  6.00       0.99     2.72
# ...

# %% [markdown]
# # Descrição do DataFame original

# %% [markdown]
# O DataFrame é constituído por 6498 linhas e 18 colunas, existem 32638 valores nulos totais.
#
# A distribuição destes valores nulos ficam da seguinte forma:
#
# -  fixed acidity              0
# -  volatile acidity           1
# -  citric acid               30
# -  residual sugar             1
# -  chlorides                  1
# -  free sulfur dioxide       31
# -  total sulfur dioxide       1
# -  density                    1
# -  pH                         1
# -  sulphates                  1
# -  alcohol                   41
# -  tipo                      38
# -  quality                    1
# -  Unnamed: 13             6498
# -  Unnamed: 14             6498
# -  Unnamed: 15             6498
# -  Unnamed: 16             6498
# -  Unnamed: 17             6498
#
# O tipo dos dados são:
#
# -  fixed acidity      : object
# -     volatile acidity:float64
# -     citric acid:float64
# -     residual sugar:float64
# -     chlorides:float64
# -     free sulfur dioxide:float64
# -     total sulfur dioxide:float64
# -     density:float64
# -     pH:float64
# -     sulphates:float64
# -    alcohol                 : object
# -    tipo                    : object
# -    quality             :float64
# -    Unnamed: 13         :float64
# -    Unnamed: 14         :float64
# -    Unnamed: 15         :float64
# -    Unnamed: 16         :float64
# -    Unnamed: 17         :float64
#
# Os dados "fixed acidity", "alcohol" são do tipo object, porém eles são valores contínuos.
#
# Excluindo a variável "tipo", todas as outras variáveis são contínuas.

# %% [markdown]
# ## Excluindo a linha com o valor "todos;os;dados;em;uma;só;célula"

# %%
df_1 = df.copy()

# %%
index_drop = df[df['fixed acidity'] == 'todos;os;dados;em;uma;só;célula'].index
df_1.drop(index_drop, axis=0, inplace=True)

# %%
df_1['fixed acidity'].value_counts()
# Out:
# fixed acidity
# 6.8     354
# 6.6     327
# 6.4     305
# 7       282
# 6.9     279
#        ...
# 13.8      1
# 13.5      1
# 14        1
# 15.9      1
# 12.1      1
# Name: count, Length: 106, dtype: int64

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 6497
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   object
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6468 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6467 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6457 non-null   object
#  11  tipo                  6460 non-null   object
#  12  quality               6497 non-null   float64
#  13  Unnamed: 13           0 non-null      float64
# ...

# %% [markdown]
# ## Convertendo as colunas contínuas do tipo 'object'

# %%
df_1['fixed acidity'] = pd.to_numeric(df_1['fixed acidity'], errors='coerce')

# %%
df_1['alcohol'] = pd.to_numeric(df_1['alcohol'], errors='coerce')

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 6497
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6468 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6467 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6417 non-null   float64
#  11  tipo                  6460 non-null   object
#  12  quality               6497 non-null   float64
#  13  Unnamed: 13           0 non-null      float64
# ...

# %% [markdown]
# # Análise descritíva e gráfica do conjunto de dados

# %% [markdown]
# ### Variável tipo

# %%
df_1['tipo'].value_counts()
# Out:
# tipo
# branco      4898
# vermelho    1562
# Name: count, dtype: int64

# %% [markdown]
# Temos duas classes para o tipo de vinho, banco com 4898 valores e banco com 1562

# %%
df_1['tipo'].mode()
# Out:
# 0    branco
# Name: tipo, dtype: object

# %% [markdown]
# A moda da variável tipo é o vinho branco

# %%
total_tipo = df_1['tipo'].value_counts().sum()
total_tipo
# Out:
# 6460

# %%
branco = round(df_1['tipo'].value_counts()[0] / total_tipo * 100, 2)
print(f'{branco}% dos dados da coluna tipo são do valor branco')
# Out:
# 75.82% dos dados da coluna tipo são do valor branco
# /tmp/ipykernel_60272/705908640.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   branco = round(df_1['tipo'].value_counts()[0] / total_tipo * 100, 2)

# %%
vermelho = round(df_1['tipo'].value_counts()[1] / total_tipo * 100, 2)
print(f'{vermelho}% dos dados da coluna tipo são do valor vermelho')
# Out:
# 24.18% dos dados da coluna tipo são do valor vermelho
# /tmp/ipykernel_60272/3135024213.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   vermelho = round(df_1['tipo'].value_counts()[1] / total_tipo * 100, 2)

# %%
ax = sns.barplot(df_1['tipo'].value_counts())

# %% [markdown]
# É possível ver a distribuição das classe e como o temos muito mais do tipo

# %% [markdown]
# ### Variável fixed acidity

# %%
round(df_1['fixed acidity'].describe(), 2)
# Out:
# count    6497.00
# mean        7.22
# std         1.30
# min         3.80
# 25%         6.40
# 50%         7.00
# 75%         7.70
# max        15.90
# Name: fixed acidity, dtype: float64

# %%
print("Skewness fixed acidity: {:.3f}".format(df_1['fixed acidity'].skew()))
print("Kurtosis fixed acidity: {:.3f}". format(df_1['fixed acidity'].kurt()))
# Out:
# Skewness fixed acidity: 1.723
# Kurtosis fixed acidity: 5.061

# %% [markdown]
# A coluna fixed acidity tem a sua descrição como:
#
# - mean        7.22
# - std         1.30
# - min         3.80
# - 25%         6.40
# - 50%         7.00
# - 75%         7.70
# - max        15.90
#
# sua média e mediana estão próximas, média igual a 7.22 e mediana igual a 7
#
# Os valores de curtose e skewness são respectivamente 5.061 e 1.723, portanto terá sua calda alongada à direita e é uma leptocúrtica.

# %%
ax = sns.histplot(df_1['fixed acidity'], stat='frequency', kde=True)
ax.set_title("Distribuição da fixed acidity", loc='center')
plt.vlines(x=df_1['fixed acidity'].mean(), ymax=3500, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['fixed acidity'].median(), ymax=3500, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['fixed acidity'].mode(), ymax=3500, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['fixed acidity'], orient='h')

# %% [markdown]
# Temos muitos outliers acima, reforçando o valor do skewness, porém tambem temos alguns dados abaixo.

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['fixed acidity'])
plt.hlines(y=df_1['fixed acidity'].mean(), xmax=7000, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['fixed acidity'].median(), xmax=7000, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['fixed acidity'].mode(), xmax=7000, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.hlines(y=8, xmax=7000, xmin=0, colors='y', linestyles='solid', label='Maior concentração dos dados')
plt.hlines(y=5, xmax=7000, xmin=0, colors='y', linestyles='solid')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Podemos observar que não segue uma distribuição linear, a maioria dos dados estão distribuidos entre 5 e 8, sendo a mioria abaixo da média, porém temos dados muito acima da média, chegando em 15.90

# %% [markdown]
# ### Variável volatile acidity

# %%
round(df_1['volatile acidity'].describe(), 2)
# Out:
# count    6497.00
# mean        1.16
# std        29.81
# min         0.08
# 25%         0.23
# 50%         0.29
# 75%         0.40
# max      1185.00
# Name: volatile acidity, dtype: float64

# %%
print("Skewness volatile acidity: {:.3f}".format(df_1['volatile acidity'].skew()))
print("Kurtosis volatile acidity: {:.3f}". format(df_1['volatile acidity'].kurt()))
# Out:
# Skewness volatile acidity: 36.230
# Kurtosis volatile acidity: 1316.525

# %% [markdown]
# A coluna volatile acidity tem a sua descrição como:
#
# - mean        1.16
# - std         29.81
# - min         0.08
# - 25%         0.23
# - 50%         0.29
# - 75%         0.40
# - max        1185.00
#
# sua média e mediana não estão tão próximas, média igual a 0.29 e mediana igual a 1.16
#
# Os valores de curtose e skewness são respectivamente 1316.525 e 36.230, portanto terá sua calda alongada à direita e é uma platicúrtica.
#
# Podemos ver que há algo de diferente, a maioria dos seus dados estão entre 0.23 e 0.40, porém seu valor máximo é 1185.00.

# %%
ax = sns.histplot(df_1['volatile acidity'], kde=True,)
ax.set_title("Distribuição da volatile acidity", loc='center')
plt.vlines(x=df_1['volatile acidity'].mean(), ymax=3500, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['volatile acidity'].median(), ymax=3500, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['volatile acidity'].mode(), ymax=3500, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['volatile acidity'], orient='h')

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['volatile acidity'])
plt.hlines(y=df_1['volatile acidity'].mean(), xmax=7000, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['volatile acidity'].median(), xmax=7000, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['volatile acidity'].mode(), xmax=7000, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Temos 5 outliers que estão muito diferentes do resto dos dados, eles se encontram entre 1000 e 1200

# %%
ax = sns.histplot(np.log(df_1['volatile acidity']), kde=True,)
ax.set_title("Distribuição da volatile acidity", loc='center')
plt.vlines(x=np.log(df_1['volatile acidity'].mean()), ymax=500, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=np.log(df_1['volatile acidity'].median()), ymax=500, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=np.log(df_1['volatile acidity'].mode()), ymax=500, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(np.log(df_1['volatile acidity']), orient='h')

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(np.log(df_1['volatile acidity']))
plt.hlines(y=np.log(df_1['volatile acidity'].mean()), xmax=7000, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=np.log(df_1['volatile acidity'].median()), xmax=7000, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=np.log(df_1['volatile acidity'].mode()), xmax=7000, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Foi feita uma transformação logarítimica para que a visualização seja possível, podemos ver como os outliers influenciam na média, a mediana e a moda ficam muito próximas uma da outra.
#
# No boxplot podemos ver que temos outliers tanto para cima quanto para baixo, mas os outliers acima de 1000, como visto nas outras visualizações, são muito discrepantes do resto dos dados.
#
# Os dados possuem uma distribuição próxima da mediana, podemos ver também o segundo pico apresentado no histograma no gráfico de pontos, onde eles se distribuem acima da mediana.

# %% [markdown]
# ## Variável citric acid

# %%
round(df_1['citric acid'].describe(), 2)
# Out:
# count    6468.00
# mean        0.32
# std         0.15
# min         0.00
# 25%         0.25
# 50%         0.31
# 75%         0.39
# max         1.66
# Name: citric acid, dtype: float64

# %%
print("Skewness citric acid: {:.3f}".format(df_1['citric acid'].skew()))
print("Kurtosis citric acid: {:.3f}". format(df_1['citric acid'].kurt()))
# Out:
# Skewness citric acid: 0.472
# Kurtosis citric acid: 2.387

# %% [markdown]
# A coluna citric acid tem a sua descrição como:
#
# - mean        0.32
# - std         0.15
# - min          0.00
# - 25%         0.25
# - 50%        0.31
# - 75%         0.39
# - max        1.66
#
# sua média e mediana estão próximas, média igual a 0.32 e mediana igual a 0.31
#
# Os valores de curtose e skewness são respectivamente 2.387 e 0.472, portanto terá sua calda alongada à direita e é uma leptocúrtica.

# %%
ax = sns.histplot(df_1['citric acid'], kde=True)
ax.set_title("Distribuição da citric acid", loc='center')
plt.vlines(x=df_1['citric acid'].mean(), ymax=700, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['citric acid'].median(), ymax=700, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['citric acid'].mode(), ymax=700, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['citric acid'], orient='h')

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['citric acid'])
plt.hlines(y=df_1['citric acid'].mean(), xmax=7000, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['citric acid'].median(), xmax=7000, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['citric acid'].mode(), xmax=7000, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Podemos ver que a distribuição é muito esparsa, ela não segue muito um padrão, porém sua média, mediana e moda são muito próximas.
#
# No histograma podemos ver dois picos, um nos dados menores e outro nos maiores que a mediana, temos também muitos outliers acima, sendo dois que mais se destacam com seus valores entre 1.25 e 1.60, enquanto o resto dos dados se concentram entre 0 e 1

# %% [markdown]
# ## Variável residual sugar

# %%
round(df_1['residual sugar'].describe(), 2)
# Out:
# count    6497.00
# mean        5.44
# std         4.76
# min         0.60
# 25%         1.80
# 50%         3.00
# 75%         8.10
# max        65.80
# Name: residual sugar, dtype: float64

# %%
print("Skewness residual sugar: {:.3f}".format(df_1['residual sugar'].skew()))
print("Kurtosis residual sugar: {:.3f}". format(df_1['residual sugar'].kurt()))
# Out:
# Skewness residual sugar: 1.435
# Kurtosis residual sugar: 4.359

# %% [markdown]
# A coluna residual sugar tem a sua descrição como:
#
# - mean       5.44
# - std         4.76
# - min         0.60
# - 25%        1.80
# - 50%         3.00
# - 75%         8.10
# - max        65.80
#
# sua média e mediana não estão tão próximas, média igual a 5.44 e mediana igual a 3.00
#
# Os valores de curtose e skewness são respectivamente 1.435 e 4.359, portanto terá sua calda alongada à direita e é uma platicúrtica,.
#
# Podemos ver que há algo de diferente, a maioria dos seus dados estão entre 0.60 e 8.10, porém seu valor máximo é 65.80.

# %%
ax = sns.histplot(df_1['residual sugar'], kde=True)
ax.set_title("Distribuição da residual sugar", loc='center')
plt.vlines(x=df_1['residual sugar'].mean(), ymax=700, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['residual sugar'].median(), ymax=700, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['residual sugar'].mode(), ymax=700, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['residual sugar'], orient='h')

# %%
iqr = df_1['residual sugar'].quantile(0.75) - df_1['residual sugar'].quantile(0.25)

fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['residual sugar'])
plt.hlines(y=df_1['residual sugar'].mean(), xmax=6500, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['residual sugar'].median(), xmax=6500, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['residual sugar'].mode(), xmax=6500, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.hlines(y=df_1['residual sugar'].quantile(0.75) + 1.5 * iqr, xmax=6500, xmin=0, colors='y', linestyles='solid', label='Limite Superior')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Podemos ver que temos muitos outlier na parte superior, sendo o maior deles 65, se destacando muito dos demais.
#
# A maioria dos dados se concentram 1.80 e 8.10 e muitos com o valor de 0.

# %% [markdown]
# ## Variável chlorides

# %%
round(df_1['chlorides'].describe(), 2)
# Out:
# count    6497.00
# mean        0.06
# std         0.04
# min         0.01
# 25%         0.04
# 50%         0.05
# 75%         0.06
# max         0.61
# Name: chlorides, dtype: float64

# %%
print("Skewness chlorides: {:.3f}".format(df_1['chlorides'].skew()))
print("Kurtosis chlorides: {:.3f}". format(df_1['chlorides'].kurt()))
# Out:
# Skewness chlorides: 5.400
# Kurtosis chlorides: 50.898

# %% [markdown]
# A coluna chlorides tem a sua descrição como:
#
# - mean        0.06
# - std         0.04
# - min         0.01
# - 25%         0.04
# - 50%         0.05
# - 75%         0.06
# - max         0.61
#
# sua média e mediana estão próximas, média igual a 0.06 e mediana igual a 0.05
#
# Os valores de curtose e skewness são respectivamente 50.898 e 5.400, portanto terá sua calda alongada à direita e é uma leptocúrtica.
#
# Podemos ver que há algo de diferente, a maioria dos seus dados estão entre 0.01 e 0.06, porém seu valor máximo é 0.61.

# %%
ax = sns.histplot(df_1['chlorides'], kde=True)
ax.set_title("Distribuição da chlorides", loc='center')
plt.vlines(x=df_1['chlorides'].mean(), ymax=700, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['chlorides'].median(), ymax=700, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['chlorides'].mode(), ymax=700, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['chlorides'], orient='h')

# %%
iqr = df_1['chlorides'].quantile(0.75) - df_1['chlorides'].quantile(0.25)

fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['chlorides'])
plt.hlines(y=df_1['chlorides'].mean(), xmax=6500, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['chlorides'].median(), xmax=6500, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['chlorides'].mode(), xmax=6500, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.hlines(y=df_1['chlorides'].quantile(0.75) + 1.5 * iqr, xmax=6500, xmin=0, colors='y', linestyles='solid', label='Limite Superior')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Podemos ver que temos muitos outliers na parte superior, indo de 0.1 até 0.61.
#
# Temos também uma grande quantidade de dados entre 0.06 e 1, criando um segundo pico no histograma.
#
# A maioria dos dados se concentram próximos a mediana em 0.05.

# %% [markdown]
# ## Variável free sulfur dioxide

# %%
round(df_1['free sulfur dioxide'].describe(), 2)
# Out:
# count    6467.00
# mean       30.50
# std        17.76
# min         1.00
# 25%        17.00
# 50%        29.00
# 75%        41.00
# max       289.00
# Name: free sulfur dioxide, dtype: float64

# %%
print("Skewness free sulfur dioxide: {:.3f}".format(df_1['free sulfur dioxide'].skew()))
print("Kurtosis free sulfur dioxide: {:.3f}". format(df_1['free sulfur dioxide'].kurt()))
# Out:
# Skewness free sulfur dioxide: 1.225
# Kurtosis free sulfur dioxide: 7.935

# %% [markdown]
# A coluna free sulfur dioxide tem a sua descrição como:
#
# - mean        30.50
# - std         17.76
# - min         1.00
# - 25%        17.00
# - 50%          29.00
# - 75%        41.00
# - max         289.00
#
# sua média e mediana estão próximas, média igual a 30.50 e mediana igual a 29.00
#
# Os valores de curtose e skewness são respectivamente 7.935 e 1.225, portanto terá sua calda alongada à direita e é uma leptocúrtica.
# Podemos ver que há algo de diferente, a maioria dos seus dados estão entre 17.00 e 41.00, porém seu valor máximo é 289.00.

# %%
ax = sns.histplot(df_1['free sulfur dioxide'], kde=True)
ax.set_title("Distribuição da free sulfur dioxide", loc='center')
plt.vlines(x=df_1['free sulfur dioxide'].mean(), ymax=700, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['free sulfur dioxide'].median(), ymax=700, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['free sulfur dioxide'].mode(), ymax=700, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['free sulfur dioxide'], orient='h')

# %%
iqr = df_1['free sulfur dioxide'].quantile(0.75) - df_1['free sulfur dioxide'].quantile(0.25)

fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['free sulfur dioxide'])
plt.hlines(y=df_1['free sulfur dioxide'].mean(), xmax=6500, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['free sulfur dioxide'].median(), xmax=6500, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['free sulfur dioxide'].mode(), xmax=6500, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.hlines(y=df_1['free sulfur dioxide'].quantile(0.75) + 1.5 * iqr, xmax=6500, xmin=0, colors='y', linestyles='solid', label='Limite Superior')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Podemos ver que existem alguns outliers na parte superior, sendo o maior deles 289.00.
#
# A sua distribuição não possui um formato de sino, apesar de sua média, media e moda estarem muito próximas.

# %% [markdown]
# ## Variável total sulfur dioxide

# %%
round(df_1['total sulfur dioxide'].describe(), 2)
# Out:
# count    6497.00
# mean      115.74
# std        56.52
# min         6.00
# 25%        77.00
# 50%       118.00
# 75%       156.00
# max       440.00
# Name: total sulfur dioxide, dtype: float64

# %%
print("Skewness total sulfur dioxide: {:.3f}".format(df_1['total sulfur dioxide'].skew()))
print("Kurtosis total sulfur dioxide: {:.3f}". format(df_1['total sulfur dioxide'].kurt()))
# Out:
# Skewness total sulfur dioxide: -0.001
# Kurtosis total sulfur dioxide: -0.372

# %% [markdown]
# A coluna total sulfur dioxide tem a sua descrição como:
#
# - mean        115.74
# - std         56.52
# - min         6.00
# - 25%        77.00
# - 50%          118.00
# - 75%        156.00
# - max         440.00
#
# sua média e mediana estão próximas, média igual a 115.74 e mediana igual a 118.00
#
# Os valores de curtose e skewness são respectivamente -0.372 e -0.001, portanto terá sua calda alongada à esquerda e é uma platicúrtica.
#
# Podemos ver que há algo de diferente, a maioria dos seus dados estão entre 6.00 e 156.00, porém seu valor máximo é 440.00.

# %%
ax = sns.histplot(df_1['total sulfur dioxide'], kde=True)
ax.set_title("Distribuição da total sulfur dioxide", loc='center')
plt.vlines(x=df_1['total sulfur dioxide'].mean(), ymax=700, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['total sulfur dioxide'].median(), ymax=700, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['total sulfur dioxide'].mode(), ymax=700, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['total sulfur dioxide'], orient='h')

# %%
iqr = df_1['total sulfur dioxide'].quantile(0.75) - df_1['total sulfur dioxide'].quantile(0.25)

fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['total sulfur dioxide'])
plt.hlines(y=df_1['total sulfur dioxide'].mean(), xmax=6500, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['total sulfur dioxide'].median(), xmax=6500, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['total sulfur dioxide'].mode(), xmax=6500, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.hlines(y=df_1['total sulfur dioxide'].quantile(0.75) + 1.5 * iqr, xmax=6500, xmin=0, colors='y', linestyles='solid', label='Limite Superior')
plt.hlines(y=5, xmax=6500, xmin=0, colors='black', linestyles='solid', label='Menor Pico')
plt.hlines(y=80, xmax=6500, xmin=0, colors='black', linestyles='solid')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Neste conjunto temos 10 outliers na parte superior, sendo o maior deles 440.
#
# Temos uma grande concentração de dados, por volta de 1500, entre 5 e 80 que são representados pelo primeiro pico no histograma.

# %% [markdown]
# ## Variável density

# %%
round(df_1['density'].describe(), 2)
# Out:
# count      6497.00
# mean        310.62
# std        4883.18
# min           0.99
# 25%           0.99
# 50%           0.99
# 75%           1.00
# max      100369.00
# Name: density, dtype: float64

# %%
df_1['density'].quantile(0.97)
# Out:
# 0.9998

# %%
print("Skewness density: {:.3f}".format(df_1['density'].skew()))
print("Kurtosis density: {:.3f}". format(df_1['density'].kurt()))
# Out:
# Skewness density: 19.814
# Kurtosis density: 401.326

# %% [markdown]
# A coluna density tem a sua descrição como:
#
# - mean       310.62
# - std          4883.18
# - min         0.99
# - 25%        0.99
# - 50%          0.99
# - 75%        1.00
# - max         100369.00
#
# sua média e mediana não estão próximas, média igual a 310.62 e mediana igual a 0.99
#
# Os valores de curtose e skewness são respectivamente 401.326 e 9.814, portanto terá sua calda alongada à direita e é uma leptocúrtica.
#
# Podemos ver que há algo de diferente, a maioria dos seus dados estão entre 0.99 e 1.00, porém seu valor máximo é 100369.00.

# %%
dados = df_1['density'] <= 1
ax = sns.histplot(np.log(dados + 1), kde=True, bins=100)
ax.set_title("Distribuição da density", loc='center')
plt.vlines(x=np.log(dados + 1).mean(), ymax=700, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=np.log(dados + 1).median(), ymax=700, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=np.log(dados + 1).mode(), ymax=700, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['density'] <= 1, orient='h')
ax.set_xlim(0.9, 1.01)
# Out:
# (0.9, 1.01)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['density'] <= 1)
ax.set_ylim(0.99, 1.01)
# Out:
# (0.99, 1.01)

# %% [markdown]
# 97.0% dos dados estão contidos entre 0.99 e 1, 3.0% são outliers, com o maior valor estando em 100369.00

# %% [markdown]
# ## Variável pH

# %%
round(df_1['pH'].describe(), 2)
# Out:
# count    6497.00
# mean        3.22
# std         0.16
# min         2.72
# 25%         3.11
# 50%         3.21
# 75%         3.32
# max         4.01
# Name: pH, dtype: float64

# %%
print("Skewness pH: {:.3f}".format(df_1['pH'].skew()))
print("Kurtosis pH: {:.3f}". format(df_1['pH'].kurt()))
# Out:
# Skewness pH: 0.387
# Kurtosis pH: 0.368

# %% [markdown]
# A coluna pH tem a sua descrição como:
#
# - mean       3.22
# - std          0.16
# - min         2.72
# - 25%        3.11
# - 50%           3.21
# - 75%         3.32
# - max         4.01
#
# sua média e mediana estão próximas, média igual a 3.22 e mediana igual a 3.21
#
# Os valores de curtose e skewness são respectivamente 0.368 e 0.387, portanto terá sua calda alongada à direita e é uma leptocúrtica.

# %%
ax = sns.histplot(df_1['pH'], kde=True)
ax.set_title("Distribuição da pH", loc='center')
plt.vlines(x=df_1['pH'].mean(), ymax=700, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['pH'].median(), ymax=700, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['pH'].mode(), ymax=700, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['pH'], orient='h')

# %%
iqr = df_1['pH'].quantile(0.75) - df_1['pH'].quantile(0.25)
iqr_2 = df_1['pH'].quantile(0.25) - df_1['pH'].quantile(0.75)

fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['pH'])
plt.hlines(y=df_1['pH'].mean(), xmax=6500, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['pH'].median(), xmax=6500, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['pH'].mode(), xmax=6500, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.hlines(y=df_1['pH'].quantile(0.75) + 1.5 * iqr, xmax=6500, xmin=0, colors='y', linestyles='solid', label='Limite Superior')
plt.hlines(y=df_1['pH'].quantile(0.25) + 1.5 * iqr_2, xmax=6500, xmin=0, colors='black', linestyles='solid', label='Limite Inferior')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Temos alguns outlier tando na parte superior quanto inferior, porém esses valor não são discrepantes do resto dos dados, como o dataset discreve as características de um vinho seus valores fazem sentido, onde seus ph's são ácidos.

# %% [markdown]
# ## Variável sulphates

# %%
round(df_1['sulphates'].describe(), 2)
# Out:
# count    6497.00
# mean        0.53
# std         0.15
# min         0.22
# 25%         0.43
# 50%         0.51
# 75%         0.60
# max         2.00
# Name: sulphates, dtype: float64

# %%
print("Skewness sulphates: {:.3f}".format(df_1['sulphates'].skew()))
print("Kurtosis sulphates: {:.3f}". format(df_1['sulphates'].kurt()))
# Out:
# Skewness sulphates: 1.797
# Kurtosis sulphates: 8.654

# %% [markdown]
# A coluna sulphates tem a sua descrição como:
#
# - mean       0.53
# - std          0.15
# - min        0.22
# - 25%        0.43
# - 50%           0.51
# - 75%         0.60
# - max         2.00
#
# sua média e mediana estão próximas, média igual a  0.53 e mediana igual a 0.51
#
# Os valores de curtose e skewness são respectivamente 8.654 e 1.797, portanto terá sua calda alongada à direita e é uma leptocúrtica.
#
# O valor máximo se destaca sendo 2, pois o conjunto se encontra entre 0.22 e 0.60

# %%
ax = sns.histplot(df_1['sulphates'], kde=True)
ax.set_title("Distribuição da sulphates", loc='center')
plt.vlines(x=df_1['sulphates'].mean(), ymax=700, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['sulphates'].median(), ymax=700, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['sulphates'].mode(), ymax=700, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['sulphates'], orient='h')

# %%
iqr = df_1['sulphates'].quantile(0.75) - df_1['sulphates'].quantile(0.25)

fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['sulphates'])
plt.hlines(y=df_1['sulphates'].mean(), xmax=6500, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['sulphates'].median(), xmax=6500, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['sulphates'].mode(), xmax=6500, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.hlines(y=df_1['sulphates'].quantile(0.75) + 1.5 * iqr, xmax=6500, xmin=0, colors='y', linestyles='solid', label='Limite Superior')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Temos alguns outliers na parte superior, tendo seu maior valor em 2.0

# %% [markdown]
# ## Variável alcohol

# %%
round(df_1['alcohol'].describe(), 2)
# Out:
# count    6417.00
# mean       10.49
# std         1.20
# min         8.00
# 25%         9.50
# 50%        10.30
# 75%        11.30
# max        14.90
# Name: alcohol, dtype: float64

# %%
print("Skewness alcohol: {:.3f}".format(df_1['alcohol'].skew()))
print("Kurtosis alcohol: {:.3f}". format(df_1['alcohol'].kurt()))
# Out:
# Skewness alcohol: 0.567
# Kurtosis alcohol: -0.537

# %% [markdown]
# A coluna alcohol tem a sua descrição como:
#
# - mean       10.49
# - std          1.20
# - min        8.00
# - 25%       9.50
# - 50%           10.30
# - 75%        11.30
# - max        14.90
#
# sua média e mediana estão próximas, média igual a  10.49 e mediana igual a 10.30
#
# Os valores de curtose e skewness são respectivamente -0.537 e 0.567, portanto terá sua calda alongada à direita e é uma platicúrtica.

# %%
ax = sns.histplot(df_1['alcohol'], kde=True)
ax.set_title("Distribuição da alcohol", loc='center')
plt.vlines(x=df_1['alcohol'].mean(), ymax=700, ymin=0, colors='r', linestyles='dashed')
plt.vlines(x=df_1['alcohol'].median(), ymax=700, ymin=0, colors='g', linestyles='dashed')
plt.vlines(x=df_1['alcohol'].mode(), ymax=700, ymin=0, colors='b', linestyles='dashed')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
ax = sns.boxplot(df_1['alcohol'], orient='h')

# %%
iqr = df_1['alcohol'].quantile(0.75) - df_1['alcohol'].quantile(0.25)

fig, ax = plt.subplots(figsize=(20, 10))
ax = sns.scatterplot(df_1['alcohol'])
plt.hlines(y=df_1['alcohol'].mean(), xmax=6500, xmin=0, colors='r', linestyles='dashed', label='Média')
plt.hlines(y=df_1['alcohol'].median(), xmax=6500, xmin=0, colors='g', linestyles='dashed', label='Mediana')
plt.hlines(y=df_1['alcohol'].mode(), xmax=6500, xmin=0, colors='b', linestyles='dashed', label='Moda')
plt.hlines(y=df_1['alcohol'].quantile(0.75) + 1.5 * iqr, xmax=6500, xmin=0, colors='y', linestyles='solid', label='Limite Superior')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# Temos uma distribuição com 3 outliers, mas eles fazem sentido com o tema do dataset, é possível um vinho ter 14.90% de álcool

# %% [markdown]
# ## Variável alvo quality

# %%
round(df_1['quality'].describe(), 2)
# Out:
# count    6497.00
# mean        5.82
# std         0.87
# min         3.00
# 25%         5.00
# 50%         6.00
# 75%         6.00
# max         9.00
# Name: quality, dtype: float64

# %%
print("Skewness quality: {:.3f}".format(df_1['quality'].skew()))
print("Kurtosis quality: {:.3f}". format(df_1['quality'].kurt()))
# Out:
# Skewness quality: 0.190
# Kurtosis quality: 0.232

# %% [markdown]
# A coluna quality tem a sua descrição como:
#
# - mean        5.82
# - std          0.87
# - min       3.00
# - 25%      5.00
# - 50%           6.00
# - 75%        6.00
# - max        9.00
#
# sua média e mediana estão próximas, média igual a  5.82 e mediana igual a 6.00
#
# Os valores de curtose e skewness são respectivamente 0.232 e 0.190, portanto terá sua calda alongada à direita e é uma leptocúrtica.

# %%
df_1['quality'].value_counts().sort_index()
# Out:
# quality
# 3.0      30
# 4.0     216
# 5.0    2138
# 6.0    2836
# 7.0    1079
# 8.0     193
# 9.0       5
# Name: count, dtype: int64

# %%
soma_dos_dados = df_1['quality'].value_counts().sum()

percentuais = [ round(df_1['quality'].value_counts().sort_index().iloc[0] / soma_dos_dados * 100, 2),
    round(df_1['quality'].value_counts().sort_index().iloc[1] / soma_dos_dados * 100, 2),
    round(df_1['quality'].value_counts().sort_index().iloc[2] / soma_dos_dados * 100, 2),
    round(df_1['quality'].value_counts().sort_index().iloc[3] / soma_dos_dados * 100, 2),
    round(df_1['quality'].value_counts().sort_index().iloc[4] / soma_dos_dados * 100, 2),
    round(df_1['quality'].value_counts().sort_index().iloc[5] / soma_dos_dados * 100, 2),
    round(df_1['quality'].value_counts().sort_index().iloc[6] / soma_dos_dados * 100, 2),
]

df_porcentagem_quality = pd.DataFrame([percentuais], columns=['3', '4', '5', '6', '7', '8', '9'])
    
ax = sns.barplot(df_porcentagem_quality)
ax.set_title("quality", loc='center')
# Out:
# Text(0.5, 1.0, 'quality')

# %%
valores_numericos = df_1.copy()
valores_numericos.drop(['tipo', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'], axis=1, inplace=True)

# %%
ax = sns.heatmap(valores_numericos.corr(), annot=True, fmt=".2f", cmap='coolwarm', annot_kws={"size": 10})
plt.figure(figsize=(20, 15))

# %% [markdown]
# Podemos analisar que o álcool tem uma grande influência na qualidade, e também que quanto menos cloreto melhor o vinho.
#
# As colunas total sulfur dioxide, fixed acidity, residual sugar, chlorides, possuem uma boa correlação com muitas das outra colunas, tanto positivamente quanto negativamente.

# %%
df_1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol    tipo  quality  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# ...
